# %%
import torch

import torch.nn as nn
import torch.nn.functional as F

from ax.service.ax_client import AxClient, ObjectiveProperties
from ax.service.utils.report_utils import exp_to_df
from ax.utils.notebook.plotting import init_notebook_plotting, render
from ax.utils.tutorials.cnn_utils import evaluate, load_mnist, train
from torch._tensor import Tensor
from torch.utils.data import DataLoader

init_notebook_plotting()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 from ax.service.utils.report_utils import exp_to_df
#       8 from ax.utils.notebook.plotting import init_notebook_plotting, render
# ----> 9 from ax.utils.tutorials.cnn_utils import evaluate, load_mnist, train
#      10 from torch._tensor import Tensor
#      11 from torch.utils.data import DataLoader
#
# File ~/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/utils/tutorials/cnn_utils.py:14
#      12 import torch.nn.functional as F
#      13 import torch.optim as optim
# ---> 14 import torchvision
#      15 import torchvision.transforms as transforms
#      16 from torch._tensor import Tensor
#
# ModuleNotFoundError: No module named 'torchvision'

# %%
from ax import optimize

# %%
best_parameters, best_values, experiment, model = optimize(
        parameters=[
          {
            "name": "x1",
            "type": "range",
            "bounds": [-10.0, 10.0],
          },
          {
            "name": "x2",
            "type": "range",
            "bounds": [-10.0, 10.0],
          },
        ],
        # Booth function
        evaluation_function=lambda p: (p["x1"] + 2*p["x2"] - 7)**2 + (2*p["x1"] + p["x2"] - 5)**2,
        minimize=True,
    )
# Out:
# [INFO 03-24 16:42:35] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x1. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 03-24 16:42:35] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x2. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 03-24 16:42:35] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='x1', parameter_type=FLOAT, range=[-10.0, 10.0]), RangeParameter(name='x2', parameter_type=FLOAT, range=[-10.0, 10.0])], parameter_constraints=[]).
# [INFO 03-24 16:42:35] ax.modelbridge.dispatch_utils: Using Models.GPEI since there are more ordered parameters than there are categories for the unordered categorical parameters.
# [INFO 03-24 16:42:35] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=2 num_trials=None use_batch_trials=False
# [INFO 03-24 16:42:35] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=5
# [INFO 03-24 16:42:35] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=5
# [INFO 03-24 16:42:35] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+GPEI', steps=[Sobol for 5 trials, GPEI for subsequent trials]). Iterations after 5 will take longer to generate due to model-fitting.
# [INFO 03-24 16:42:35] ax.service.managed_loop: Started full optimization with 20 steps.
# [INFO 03-24 16:42:35] ax.service.managed_loop: Running optimization trial 1...
# [INFO 03-24 16:42:35] ax.service.managed_loop: Running optimization trial 2...
# [INFO 03-24 16:42:35] ax.service.managed_loop: Running optimization trial 3...
# [INFO 03-24 16:42:35] ax.service.managed_loop: Running optimization trial 4...
# [INFO 03-24 16:42:35] ax.service.managed_loop: Running optimization trial 5...
# [INFO 03-24 16:42:35] ax.service.managed_loop: Running optimization trial 6...
# [INFO 03-24 16:42:36] ax.service.managed_loop: Running optimization trial 7...
# [INFO 03-24 16:42:36] ax.service.managed_loop: Running optimization trial 8...
# [INFO 03-24 16:42:36] ax.service.managed_loop: Running optimization trial 9...
# [INFO 03-24 16:42:37] ax.service.managed_loop: Running optimization trial 10...
# [INFO 03-24 16:42:37] ax.service.managed_loop: Running optimization trial 11...
# [INFO 03-24 16:42:37] ax.service.managed_loop: Running optimization trial 12...
# [INFO 03-24 16:42:38] ax.service.managed_loop: Running optimization trial 13...
# [INFO 03-24 16:42:38] ax.service.managed_loop: Running optimization trial 14...
# [INFO 03-24 16:42:38] ax.service.managed_loop: Running optimization trial 15...
# [INFO 03-24 16:42:39] ax.service.managed_loop: Running optimization trial 16...
# [INFO 03-24 16:42:39] ax.service.managed_loop: Running optimization trial 17...
# [INFO 03-24 16:42:40] ax.service.managed_loop: Running optimization trial 18...
# [INFO 03-24 16:42:40] ax.service.managed_loop: Running optimization trial 19...
# [INFO 03-24 16:42:41] ax.service.managed_loop: Running optimization trial 20...

# %%
best_parameters
# Out:
# {'x1': 0.9185325865691762, 'x2': 3.110823735817787}

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from dockstring import load_target
import random

# Assuming mutate_molecule is correctly defined elsewhere
# from your_mutation_logic import mutate_molecule

# Importing necessary components from Ax
from ax.service.ax_client import AxClient
from ax.utils.notebook.plotting import render

# Load the target protein
target = load_target('DRD2')

# Define the initial ligand
initial_ligand = Chem.MolFromSmiles("c1ccccc1C(=O)Nc2ccccc2")

# Initialize AxClient and create an experiment with a single objective
ax_client = AxClient()
ax_client.create_experiment(
    name="docking_optimization",
    parameters=[
        {"name": "mutation_rate", "type": "range", "bounds": [0.0, 1.0], "value_type": "float"},
        {"name": "mutation_type", "type": "choice", "values": ["insert", "remove", "replace"], "value_type": "str"},
    ],
    objective_name="binding_score",
    minimize=False  # Set to False to maximize the objective
)

# Define the objective function
def objective_function(parameterization):
    mutation_rate = parameterization.get('mutation_rate')
    mutation_type = parameterization.get('mutation_type')

    # Apply mutations to the initial ligand
    mutated_mol = mutate_molecule(initial_ligand, mutation_rate, mutation_type)

    # Score the mutated molecule using dockstring
    score, _ = target.dock(Chem.MolToSmiles(mutated_mol))

    return {"binding_score": (score, 0.0)}  # Assuming score is a float. The 0.0 is the SEM (standard error of the mean).

# Run the optimization loop
for _ in range(25):  # Adjust the number of iterations as needed
    parameters, trial_index = ax_client.get_next_trial()
    ax_client.complete_trial(trial_index=trial_index, raw_data=objective_function(parameters))

# Extract the best parameters and score
best_parameters, metrics = ax_client.get_best_parameters()
best_score = metrics["binding_score"]

print(f"Best parameters: {best_parameters}")
print(f"Best binding score: {best_score}")

# Visualize the best molecule
best_mol = mutate_molecule(
    initial_ligand,
    best_parameters['mutation_rate'],
    best_parameters['mutation_type']
)
Draw.MolToFile(best_mol, 'best_molecule.png')
# Out:
# [INFO 03-24 16:47:13] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/core/parameter.py:517: UserWarning:
#
# `is_ordered` is not specified for `ChoiceParameter` "mutation_type". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `is_ordered` during `ChoiceParameter` construction.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/core/parameter.py:517: UserWarning:
#
# `sort_values` is not specified for `ChoiceParameter` "mutation_type". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `sort_values` during `ChoiceParameter` construction.
#
# [INFO 03-24 16:47:13] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='mutation_rate', parameter_type=FLOAT, range=[0.0, 1.0]), ChoiceParameter(name='mutation_type', parameter_type=STRING, values=['insert', 'remove', 'replace'], is_ordered=False, sort_values=False)], parameter_constraints=[]).
# [INFO 03-24 16:47:13] ax.modelbridge.dispatch_utils: Using Bayesian optimization with a categorical kernel for improved performance with a large number of unordered categorical parameters.
# [INFO 03-24 16:47:13] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=2 num_trials=None use_batch_trials=False
# [INFO 03-24 16:47:13] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=5
# [INFO 03-24 16:47:13] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=5
# [INFO 03-24 16:47:13] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BO_MIXED', steps=[Sobol for 5 trials, BO_MIXED for subsequent trials]). Iterations after 5 will take longer to generate due to model-fitting.
# [INFO 03-24 16:47:13] ax.service.ax_client: Generated new trial 0 with parameters {'mutation_rate': 0.777092, 'mutation_type': 'insert'}.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 47
#      45 for _ in range(25):  # Adjust the number of iterations as needed
#      46     parameters, trial_index = ax_client.get_next_trial()
# ---> 47     ax_client.complete_trial(trial_index=trial_index, raw_data=objective_function(parameters))
#      49 # Extract the best parameters and score
#      50 best_parameters, metrics = ax_client.get_best_parameters()
#
# Cell In[13], line 37, in objective_function(parameterization)
#      34 mutation_type = parameterization.get('mutation_type')
#      36 # Apply mutations to the initial ligand
# ---> 37 mutated_mol = mutate_molecule(initial_ligand, mutation_rate, mutation_type)
#      39 # Score the mutated molecule using dockstring
#      40 score, _ = target.dock(Chem.MolToSmiles(mutated_mol))
#
# TypeError: mutate_molecule() takes 1 positional argument but 3 were given

# %%
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
import random

def mutate_molecule(smiles):
    mol = Chem.MolFromSmiles(smiles)
    mutation_type = random.choice(['add_functional_group', 'modify_ring', 'change_chain_length'])
    
    if mutation_type == 'add_functional_group':
        # Example: Add a hydroxyl group to a random carbon atom
        carbons = [atom.GetIdx() for atom in mol.GetAtoms() if atom.GetSymbol() == 'C']
        if carbons:
            c = random.choice(carbons)
            mol = Chem.RWMol(mol)
            oh = Chem.MolFromSmiles('O')
            mol.AddBond(c, mol.AddAtom(oh.GetAtomWithIdx(0)), Chem.BondType.SINGLE)
            mol = mol.GetMol()
    
    elif mutation_type == 'modify_ring':
        # Example: Simplified version, convert a benzene ring to a pyridine (if present)
        patterns = [Chem.MolFromSmarts('c1ccccc1')]  # A benzene ring
        for pattern in patterns:
            if mol.HasSubstructMatch(pattern):
                replacement = Chem.MolFromSmiles('c1ccncc1')  # Pyridine
                mol = AllChem.ReplaceSubstructs(mol, pattern, replacement)[0]
                break

    elif mutation_type == 'change_chain_length':
        # Example: Extend a carbon chain by one carbon atom
        # Find the first carbon with fewer than 4 neighbors to add a methyl group
        for atom in mol.GetAtoms():
            if atom.GetSymbol() == 'C' and len(atom.GetNeighbors()) < 4:
                mol = Chem.RWMol(mol)
                c = mol.AddAtom(Chem.Atom('C'))
                mol.AddBond(atom.GetIdx(), c, Chem.BondType.SINGLE)
                mol = mol.GetMol()
                break

    return Chem.MolToSmiles(mol)

# Test the mutation function
initial_smiles = "c1ccccc1C(=O)Nc2ccccc2"  # An initial ligand
mutated_smiles = mutate_molecule(initial_smiles)
print(f"Initial SMILES: {initial_smiles}")
print(f"Mutated SMILES: {mutated_smiles}")
# Out:
# Initial SMILES: c1ccccc1C(=O)Nc2ccccc2
# Mutated SMILES: Cc1ccccc1C(=O)Nc1ccccc1

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from dockstring import load_target
import random

# Importing necessary components from Ax
from ax.service.ax_client import AxClient
from ax.utils.notebook.plotting import render

# Define the mutate_molecule function to accept mutation_rate and mutation_type
def mutate_molecule(smiles, mutation_rate, mutation_type):
    mol = Chem.MolFromSmiles(smiles)
    # Placeholder for mutation logic; should be implemented based on specific criteria
    if mutation_type == 'insert':
        # For simplicity, we won't implement detailed mutation logic here
        pass  # Implement add_functional_group logic
    elif mutation_type == 'remove':
        pass  # Implement remove_functional_group logic
    elif mutation_type == 'replace':
        pass  # Implement replace_functional_group logic
    return Chem.MolToSmiles(mol)  # Return the modified SMILES string

# Load the target protein
target = load_target('DRD2')

# Define the initial ligand
initial_ligand = Chem.MolFromSmiles("c1ccccc1C(=O)Nc2ccccc2")

# Initialize AxClient and create an experiment with a single objective
ax_client = AxClient()
ax_client.create_experiment(
    name="docking_optimization",
    parameters=[
        {"name": "mutation_rate", "type": "range", "bounds": [0.0, 1.0], "value_type": "float"},
        {"name": "mutation_type", "type": "choice", "values": ["insert", "remove", "replace"], "value_type": "str"},
    ],
    objective_name="binding_score",
    minimize=False  # Set to False to maximize the objective
)

# Define the objective function
def objective_function(parameterization):
    mutation_rate = parameterization.get('mutation_rate')
    mutation_type = parameterization.get('mutation_type')

    # Apply mutations to the initial ligand
    mutated_smiles = mutate_molecule(Chem.MolToSmiles(initial_ligand), mutation_rate, mutation_type)

    # Score the mutated molecule using dockstring
    score, _ = target.dock(mutated_smiles)

    return {"binding_score": (score, 0.0)}  # Assuming score is a float. The 0.0 is the SEM.

# Run the optimization loop
for _ in range(25):  # Adjust the number of iterations as needed
    parameters, trial_index = ax_client.get_next_trial()
    ax_client.complete_trial(trial_index=trial_index, raw_data=objective_function(parameters))

# Extract the best parameters and score
best_parameters, metrics = ax_client.get_best_parameters()
best_score = metrics["binding_score"]

print(f"Best parameters: {best_parameters}")
print(f"Best binding score: {best_score}")

# Visualize the best molecule
best_mol_smiles = mutate_molecule(
    Chem.MolToSmiles(initial_ligand),
    best_parameters['mutation_rate'],
    best_parameters['mutation_type']
)
best_mol = Chem.MolFromSmiles(best_mol_smiles)
Draw.MolToFile(best_mol, 'best_molecule.png')
# Out:
# [INFO 03-24 16:50:13] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/core/parameter.py:517: UserWarning:
#
# `is_ordered` is not specified for `ChoiceParameter` "mutation_type". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `is_ordered` during `ChoiceParameter` construction.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/core/parameter.py:517: UserWarning:
#
# `sort_values` is not specified for `ChoiceParameter` "mutation_type". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `sort_values` during `ChoiceParameter` construction.
#
# [INFO 03-24 16:50:13] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='mutation_rate', parameter_type=FLOAT, range=[0.0, 1.0]), ChoiceParameter(name='mutation_type', parameter_type=STRING, values=['insert', 'remove', 'replace'], is_ordered=False, sort_values=False)], parameter_constraints=[]).
# [INFO 03-24 16:50:13] ax.modelbridge.dispatch_utils: Using Bayesian optimization with a categorical kernel for improved performance with a large number of unordered categorical parameters.
# [INFO 03-24 16:50:13] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=2 num_trials=None use_batch_trials=False
# [INFO 03-24 16:50:13] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=5
# [INFO 03-24 16:50:13] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=5
# [INFO 03-24 16:50:13] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BO_MIXED', steps=[Sobol for 5 trials, BO_MIXED for subsequent trials]). Iterations after 5 will take longer to generate due to model-fitting.
# [INFO 03-24 16:50:13] ax.service.ax_client: Generated new trial 0 with parameters {'mutation_rate': 0.97402, 'mutation_type': 'remove'}.
# [INFO 03-24 16:50:17] ax.service.ax_client: Completed trial 0 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:50:17] ax.service.ax_client: Generated new trial 1 with parameters {'mutation_rate': 0.061505, 'mutation_type': 'insert'}.
# [INFO 03-24 16:50:21] ax.service.ax_client: Completed trial 1 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:50:21] ax.service.ax_client: Generated new trial 2 with parameters {'mutation_rate': 0.39178, 'mutation_type': 'replace'}.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 57
#      55 for _ in range(25):  # Adjust the number of iterations as needed
#      56     parameters, trial_index = ax_client.get_next_trial()
# ---> 57     ax_client.complete_trial(trial_index=trial_index, raw_data=objective_function(parameters))
#      59 # Extract the best parameters and score
#      60 best_parameters, metrics = ax_client.get_best_parameters()
#
# Cell In[14], line 50, in objective_function(parameterization)
#      47 mutated_smiles = mutate_molecule(Chem.MolToSmiles(initial_ligand), mutation_rate, mutation_type)
#      49 # Score the mutated molecule using dockstring
# ---> 50 score, _ = target.dock(mutated_smiles)
#      52 return {"binding_score": (score, 0.0)}
#
# File ~/miniconda3/envs/newenv/lib/python3.8/site-packages/dockstring/target.py:209, in Target.dock(self, smiles, pH, num_cpus, seed, verbose)
#     207 write_mol_to_mol_file(refined_mol, ligand_mol_file)
#     208 convert_mol_file_to_pdbqt(ligand_mol_file, ligand_pdbqt)
# --> 209 self._dock_pdbqt(ligand_pdbqt, vina_logfile, vina_outfile, seed=seed, num_cpus=num_cpus)
#     211 # Process docking output
#     212 try:
#
# File ~/miniconda3/envs/newenv/lib/python3.8/site-packages/dockstring/target.py:152, in Target._dock_pdbqt(self, pdbqt_path, log_path, out_path, seed, num_cpus)
#     149 if num_cpus is not None:
#     150     cmd_list += ['--cpu', str(num_cpus)]
# --> 152 cmd_return = subprocess.run(cmd_list, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
#     153 output = cmd_return.stdout.decode('utf-8')
#     154 logging.debug(output)
#
# File ~/miniconda3/envs/newenv/lib/python3.8/subprocess.py:495, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
# --> 495         stdout, stderr = process.communicate(input, timeout=timeout)
#     496     except TimeoutExpired as exc:
#     497         process.kill()
#
# File ~/miniconda3/envs/newenv/lib/python3.8/subprocess.py:1015, in Popen.communicate(self, input, timeout)
#    1013     self._stdin_write(input)
#    1014 elif self.stdout:
# -> 1015     stdout = self.stdout.read()
#    1016     self.stdout.close()
#    1017 elif self.stderr:
#
# KeyboardInterrupt:

# %%
from rdkit import Chem
from rdkit.Chem import Draw, rdmolops
from dockstring import load_target
import random
from rdkit.Chem import Descriptors

# Importing necessary components from Ax
from ax.service.ax_client import AxClient
from ax.utils.notebook.plotting import render

def mutate_molecule(smiles, mutation_rate, mutation_type):
    mol = Chem.MolFromSmiles(smiles)
    if random.random() < mutation_rate:
        if mutation_type == 'insert':
            # Example: append a hydroxyl group; in practice, choose a suitable attachment point
            smiles += 'O'
        elif mutation_type == 'remove':
            # Simplified removal; identify removable parts for a more realistic approach
            mol = Chem.RemoveHs(mol)  # Placeholder for actual removal logic
            smiles = Chem.MolToSmiles(mol)
        elif mutation_type == 'replace':
            # Simplified replace; identify and replace specific functional groups in SMILES
            smiles = smiles.replace('Cl', 'Br')  # Example replacement
        mol = Chem.MolFromSmiles(smiles)
    return Chem.MolToSmiles(mol)

# Load the target protein
target = load_target('DRD2')

# Define the initial ligand
initial_ligand = Chem.MolFromSmiles("c1ccccc1C(=O)Nc2ccccc2")

# Initialize AxClient and create an experiment with a single objective
ax_client = AxClient()
ax_client.create_experiment(
    name="docking_optimization",
    parameters=[
        {"name": "mutation_rate", "type": "range", "bounds": [0.0, 1.0], "value_type": "float"},
        {"name": "mutation_type", "type": "choice", "values": ["insert", "remove", "replace"], "value_type": "str"},
    ],
    objective_name="binding_score",
    minimize=False  # Set to False to maximize the objective
)

# Define the objective function
def objective_function(parameterization):
    mutation_rate = parameterization.get('mutation_rate')
    mutation_type = parameterization.get('mutation_type')
    mutated_smiles = mutate_molecule(Chem.MolToSmiles(initial_ligand), mutation_rate, mutation_type)
    mutated_mol = Chem.MolFromSmiles(mutated_smiles)

    # Score the mutated molecule using dockstring
    score, _ = target.dock(mutated_smiles)



    return {"binding_score": (score, 0.0)}
# Run the optimization loop
for _ in range(25):  # Adjust the number of iterations as needed
    parameters, trial_index = ax_client.get_next_trial()
    ax_client.complete_trial(trial_index=trial_index, raw_data=objective_function(parameters))

# Extract the best parameters and score
best_parameters, metrics = ax_client.get_best_parameters()
best_score = metrics["binding_score"]

print(f"Best parameters: {best_parameters}")
print(f"Best binding score: {best_score}")

# Visualize the best molecule
best_mol_smiles = mutate_molecule(
    Chem.MolToSmiles(initial_ligand),
    best_parameters['mutation_rate'],
    best_parameters['mutation_type']
)
best_mol = Chem.MolFromSmiles(best_mol_smiles)
Draw.MolToFile(best_mol, 'best_molecule.png')
# Out:
# [INFO 03-24 16:56:24] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/core/parameter.py:517: UserWarning:
#
# `is_ordered` is not specified for `ChoiceParameter` "mutation_type". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `is_ordered` during `ChoiceParameter` construction.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/core/parameter.py:517: UserWarning:
#
# `sort_values` is not specified for `ChoiceParameter` "mutation_type". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `sort_values` during `ChoiceParameter` construction.
#
# [INFO 03-24 16:56:24] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='mutation_rate', parameter_type=FLOAT, range=[0.0, 1.0]), ChoiceParameter(name='mutation_type', parameter_type=STRING, values=['insert', 'remove', 'replace'], is_ordered=False, sort_values=False)], parameter_constraints=[]).
# [INFO 03-24 16:56:24] ax.modelbridge.dispatch_utils: Using Bayesian optimization with a categorical kernel for improved performance with a large number of unordered categorical parameters.
# [INFO 03-24 16:56:24] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=2 num_trials=None use_batch_trials=False
# [INFO 03-24 16:56:24] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=5
# [INFO 03-24 16:56:24] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=5
# [INFO 03-24 16:56:24] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BO_MIXED', steps=[Sobol for 5 trials, BO_MIXED for subsequent trials]). Iterations after 5 will take longer to generate due to model-fitting.
# [INFO 03-24 16:56:24] ax.service.ax_client: Generated new trial 0 with parameters {'mutation_rate': 0.686086, 'mutation_type': 'replace'}.
# [INFO 03-24 16:56:28] ax.service.ax_client: Completed trial 0 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:56:28] ax.service.ax_client: Generated new trial 1 with parameters {'mutation_rate': 0.318171, 'mutation_type': 'insert'}.
# [INFO 03-24 16:56:32] ax.service.ax_client: Completed trial 1 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:56:32] ax.service.ax_client: Generated new trial 2 with parameters {'mutation_rate': 0.030649, 'mutation_type': 'insert'}.
# [INFO 03-24 16:56:37] ax.service.ax_client: Completed trial 2 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:56:37] ax.service.ax_client: Generated new trial 3 with parameters {'mutation_rate': 0.500035, 'mutation_type': 'replace'}.
# [INFO 03-24 16:56:41] ax.service.ax_client: Completed trial 3 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:56:41] ax.service.ax_client: Generated new trial 4 with parameters {'mutation_rate': 0.991906, 'mutation_type': 'insert'}.
# [INFO 03-24 16:56:46] ax.service.ax_client: Completed trial 4 with data: {'binding_score': (-9.0, 0.0)}.
# [INFO 03-24 16:56:46] ax.modelbridge.transforms.standardize_y: Outcome binding_score is constant, within tolerance.
# [WARNING 03-24 16:56:46] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/models/torch/botorch_modular/surrogate.py:301: AxWarning:
#
# Provided model class <class 'botorch.models.gp_regression_mixed.MixedSingleTaskGP'> does not accept `train_Yvar` argument, but received `FixedNoiseDataset`. Ignoring variance observations and converting to `SupervisedDataset`.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/botorch/models/utils/assorted.py:201: InputDataWarning:
#
# Input data is not standardized. Please consider scaling the input to zero mean and unit variance.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/gpytorch/distributions/multivariate_normal.py:319: NumericalWarning:
#
# Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-10.
#
# [INFO 03-24 16:56:46] ax.service.ax_client: Generated new trial 5 with parameters {'mutation_rate': 0.000242, 'mutation_type': 'remove'}.
# [INFO 03-24 16:56:50] ax.service.ax_client: Completed trial 5 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:56:50] ax.modelbridge.transforms.standardize_y: Outcome binding_score is constant, within tolerance.
# [WARNING 03-24 16:56:50] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/models/torch/botorch_modular/surrogate.py:301: AxWarning:
#
# Provided model class <class 'botorch.models.gp_regression_mixed.MixedSingleTaskGP'> does not accept `train_Yvar` argument, but received `FixedNoiseDataset`. Ignoring variance observations and converting to `SupervisedDataset`.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/botorch/models/utils/assorted.py:201: InputDataWarning:
#
# Input data is not standardized. Please consider scaling the input to zero mean and unit variance.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/gpytorch/distributions/multivariate_normal.py:319: NumericalWarning:
#
# Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-10.
#
# [INFO 03-24 16:56:51] ax.service.ax_client: Generated new trial 6 with parameters {'mutation_rate': 0.999954, 'mutation_type': 'remove'}.
# [INFO 03-24 16:56:55] ax.service.ax_client: Completed trial 6 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:56:55] ax.modelbridge.transforms.standardize_y: Outcome binding_score is constant, within tolerance.
# [WARNING 03-24 16:56:55] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/models/torch/botorch_modular/surrogate.py:301: AxWarning:
#
# Provided model class <class 'botorch.models.gp_regression_mixed.MixedSingleTaskGP'> does not accept `train_Yvar` argument, but received `FixedNoiseDataset`. Ignoring variance observations and converting to `SupervisedDataset`.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/botorch/models/utils/assorted.py:201: InputDataWarning:
#
# Input data is not standardized. Please consider scaling the input to zero mean and unit variance.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/gpytorch/distributions/multivariate_normal.py:319: NumericalWarning:
#
# Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-10.
#
# [INFO 03-24 16:56:55] ax.service.ax_client: Generated new trial 7 with parameters {'mutation_rate': 0.00032, 'mutation_type': 'replace'}.
# [INFO 03-24 16:57:00] ax.service.ax_client: Completed trial 7 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:57:00] ax.modelbridge.transforms.standardize_y: Outcome binding_score is constant, within tolerance.
# [WARNING 03-24 16:57:00] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/models/torch/botorch_modular/surrogate.py:301: AxWarning:
#
# Provided model class <class 'botorch.models.gp_regression_mixed.MixedSingleTaskGP'> does not accept `train_Yvar` argument, but received `FixedNoiseDataset`. Ignoring variance observations and converting to `SupervisedDataset`.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/botorch/models/utils/assorted.py:201: InputDataWarning:
#
# Input data is not standardized. Please consider scaling the input to zero mean and unit variance.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/gpytorch/distributions/multivariate_normal.py:319: NumericalWarning:
#
# Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-10.
#
# [INFO 03-24 16:57:00] ax.service.ax_client: Generated new trial 8 with parameters {'mutation_rate': 0.500008, 'mutation_type': 'replace'}.
# [INFO 03-24 16:57:04] ax.service.ax_client: Completed trial 8 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:57:04] ax.modelbridge.transforms.standardize_y: Outcome binding_score is constant, within tolerance.
# [WARNING 03-24 16:57:04] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/models/torch/botorch_modular/surrogate.py:301: AxWarning:
#
# Provided model class <class 'botorch.models.gp_regression_mixed.MixedSingleTaskGP'> does not accept `train_Yvar` argument, but received `FixedNoiseDataset`. Ignoring variance observations and converting to `SupervisedDataset`.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/botorch/models/utils/assorted.py:201: InputDataWarning:
#
# Input data is not standardized. Please consider scaling the input to zero mean and unit variance.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/gpytorch/distributions/multivariate_normal.py:319: NumericalWarning:
#
# Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-10.
#
# [INFO 03-24 16:57:04] ax.service.ax_client: Generated new trial 9 with parameters {'mutation_rate': 0.999848, 'mutation_type': 'replace'}.
# [INFO 03-24 16:57:09] ax.service.ax_client: Completed trial 9 with data: {'binding_score': (-8.7, 0.0)}.
# [INFO 03-24 16:57:09] ax.modelbridge.transforms.standardize_y: Outcome binding_score is constant, within tolerance.
# [WARNING 03-24 16:57:09] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/ax/models/torch/botorch_modular/surrogate.py:301: AxWarning:
#
# Provided model class <class 'botorch.models.gp_regression_mixed.MixedSingleTaskGP'> does not accept `train_Yvar` argument, but received `FixedNoiseDataset`. Ignoring variance observations and converting to `SupervisedDataset`.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/botorch/models/utils/assorted.py:201: InputDataWarning:
#
# Input data is not standardized. Please consider scaling the input to zero mean and unit variance.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/linear_operator/utils/cholesky.py:40: NumericalWarning:
#
# A not p.d., added jitter of 1.0e-08 to the diagonal
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning:
#
# Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning:
#
# Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/botorch/optim/initializers.py:403: BadInitialCandidatesWarning:
#
# Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#
# /home/alxfgh/miniconda3/envs/newenv/lib/python3.8/site-packages/gpytorch/distributions/multivariate_normal.py:319: NumericalWarning:
#
# Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-10.
#
# [INFO 03-24 16:57:11] ax.service.ax_client: Generated new trial 10 with parameters {'mutation_rate': 0.507189, 'mutation_type': 'insert'}.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 61
#      59 for _ in range(25):  # Adjust the number of iterations as needed
#      60     parameters, trial_index = ax_client.get_next_trial()
# ---> 61     ax_client.complete_trial(trial_index=trial_index, raw_data=objective_function(parameters))
#      63 # Extract the best parameters and score
#      64 best_parameters, metrics = ax_client.get_best_parameters()
#
# Cell In[17], line 53, in objective_function(parameterization)
#      50 mutated_mol = Chem.MolFromSmiles(mutated_smiles)
#      52 # Score the mutated molecule using dockstring
# ---> 53 score, _ = target.dock(mutated_smiles)
#      57 return {"binding_score": (score, 0.0)}
#
# File ~/miniconda3/envs/newenv/lib/python3.8/site-packages/dockstring/target.py:209, in Target.dock(self, smiles, pH, num_cpus, seed, verbose)
#     207 write_mol_to_mol_file(refined_mol, ligand_mol_file)
#     208 convert_mol_file_to_pdbqt(ligand_mol_file, ligand_pdbqt)
# --> 209 self._dock_pdbqt(ligand_pdbqt, vina_logfile, vina_outfile, seed=seed, num_cpus=num_cpus)
#     211 # Process docking output
#     212 try:
#
# File ~/miniconda3/envs/newenv/lib/python3.8/site-packages/dockstring/target.py:152, in Target._dock_pdbqt(self, pdbqt_path, log_path, out_path, seed, num_cpus)
#     149 if num_cpus is not None:
#     150     cmd_list += ['--cpu', str(num_cpus)]
# --> 152 cmd_return = subprocess.run(cmd_list, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
#     153 output = cmd_return.stdout.decode('utf-8')
#     154 logging.debug(output)
#
# File ~/miniconda3/envs/newenv/lib/python3.8/subprocess.py:495, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
# --> 495         stdout, stderr = process.communicate(input, timeout=timeout)
#     496     except TimeoutExpired as exc:
#     497         process.kill()
#
# File ~/miniconda3/envs/newenv/lib/python3.8/subprocess.py:1015, in Popen.communicate(self, input, timeout)
#    1013     self._stdin_write(input)
#    1014 elif self.stdout:
# -> 1015     stdout = self.stdout.read()
#    1016     self.stdout.close()
#    1017 elif self.stderr:
#
# KeyboardInterrupt:
